# %% [markdown]
# # 3. The Lox Language

# %% [markdown]
# Dyanamic Typing
# - variables can be store values of any type and single variable can store different types at different times

# %% [markdown]
# ## Automatic Memory Management
#
# high level languages exists to eliminate error prone, low level drudgery. Ex of tedious task includes manually mananging the allocation and freeing of storage
#
# 2 main techniques for memory management:
# - reference counting
# - tracing garbage collection

# %% [markdown]
# ## Data Types
#
# - booleans: true and false
# - numbers: lox only has one type of number (double precision floating point)
# - strings: enclosed in double quotes
# - Nil: "no value" or null

# %% [markdown]
# ## Expressions

# %% [markdown]
# -

# %% [markdown]
# ## Classes Or Prototypes
#
# Classes:
# - classes contains the methods and inheritance chain
#     - instances store the state for each object and have a reference to the instance's class
#     - classes contains the methods and inheritance chain
# - static dispatch
#     - method lookup typically happens at compile time based on the static type of the instance
# - dynamic dispatch
#     - look up the class of the actual instance object at runtime
#
#
# Prototype:
# - only object no class
# - each individual object contain state and method
